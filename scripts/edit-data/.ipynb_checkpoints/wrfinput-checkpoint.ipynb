# %%
from netCDF4 import Dataset
from glob import glob
import sys, os

is_py = os.path.basename(sys.argv[0]) == 'wrfinput.ju.py'
RUN_ID = int(sys.argv[1]) if is_py and len(sys.argv) > 1 else 1

root_dir = '/home/guc/'
data_dir = f'runs/{RUN_ID:03}*/'
root_data_dir = glob(root_dir + data_dir)[0]

all_files = glob(root_data_dir + 'wrfinput*')

# %%
def list_landuse(dataset: Dataset) -> None:
    attrs = dataset.__dict__
    print(f'Land use category (MMINLU), check with WRF/LANDUSE.TBL: {attrs['MMINLU']}')
    print(f'Land use category number (NUM_LAND_CAT): {attrs['NUM_LAND_CAT']}')
    print(f'Water type index (ISWATER): {attrs['ISWATER']}')
    print(f'Urban type index (ISWATER): {attrs['ISURBAN']}')

# show_lu()
# list_landuse()

# %%
import matplotlib.pyplot as plt
import math

def list_variables(dataset: Dataset) -> None:
    '''
    List all variables in the nc dataset for adjustment
    dataset:    netcdf dataset
    '''
    print('\n'.join(map(lambda x: f'{x.name}: {dataset[x.name].__dict__.get('description')} {x.dimensions}', dataset.variables.values())))

dataset = Dataset(all_files[0], format="NETCDF4")
list_variables(dataset)
# Out:
# Times: None ('Time', 'DateStrLen')
# XLAT: LATITUDE, SOUTH IS NEGATIVE ('Time', 'south_north', 'west_east')
# XLONG: LONGITUDE, WEST IS NEGATIVE ('Time', 'south_north', 'west_east')
# LU_INDEX: LAND USE CATEGORY ('Time', 'south_north', 'west_east')
# ZNU: eta values on half (mass) levels ('Time', 'bottom_top')
# ZNW: eta values on full (w) levels ('Time', 'bottom_top_stag')
# ZS: DEPTHS OF CENTERS OF SOIL LAYERS ('Time', 'soil_layers_stag')
# DZS: THICKNESSES OF SOIL LAYERS ('Time', 'soil_layers_stag')
# VAR_SSO: variance of subgrid-scale orography ('Time', 'south_north', 'west_east')
# EROD: fraction of erodible surface in each grid cell (0-1) ('Time', 'dust_erosion_dimension', 'south_north', 'west_east')
# BATHYMETRY_FLAG: Flag for bathymetry in the global attributes for metgrid data ('Time',)
# U: x-wind component ('Time', 'bottom_top', 'south_north', 'west_east_stag')
# V: y-wind component ('Time', 'bottom_top', 'south_north_stag', 'west_east')
# W: z-wind component ('Time', 'bottom_top_stag', 'south_north', 'west_east')
# PH: perturbation geopotential ('Time', 'bottom_top_stag', 'south_north', 'west_east')
# PHB: base-state geopotential ('Time', 'bottom_top_stag', 'south_north', 'west_east')
# T: perturbation potential temperature theta-t0 ('Time', 'bottom_top', 'south_north', 'west_east')
# THM: either 1) pert moist pot temp=(1+Rv/Rd Qv)*(theta)-T0, or 2) pert dry pot temp=t ('Time', 'bottom_top', 'south_north', 'west_east')
# T_INIT: initial potential temperature ('Time', 'bottom_top', 'south_north', 'west_east')
# MU: perturbation dry air mass in column ('Time', 'south_north', 'west_east')
# MUB: base state dry air mass in column ('Time', 'south_north', 'west_east')
# P: perturbation pressure ('Time', 'bottom_top', 'south_north', 'west_east')
# AL: inverse perturbation density ('Time', 'bottom_top', 'south_north', 'west_east')
# ALB: inverse base density ('Time', 'bottom_top', 'south_north', 'west_east')
# PB: BASE STATE PRESSURE ('Time', 'bottom_top', 'south_north', 'west_east')
# FNM: upper weight for vertical stretching ('Time', 'bottom_top')
# FNP: lower weight for vertical stretching ('Time', 'bottom_top')
# RDNW: inverse d(eta) values between full (w) levels ('Time', 'bottom_top')
# RDN: inverse d(eta) values between half (mass) levels ('Time', 'bottom_top')
# DNW: d(eta) values between full (w) levels ('Time', 'bottom_top')
# DN: d(eta) values between half (mass) levels ('Time', 'bottom_top')
# T_BASE: BASE STATE T IN IDEALIZED CASES ('Time', 'bottom_top')
# CFN: extrapolation constant ('Time',)
# CFN1: extrapolation constant ('Time',)
# STEP_NUMBER:  ('Time',)
# THIS_IS_AN_IDEAL_RUN: T/F flag: this is an ARW ideal simulation ('Time',)
# P_HYD: hydrostatic pressure ('Time', 'bottom_top', 'south_north', 'west_east')
# Q2: QV at 2 M ('Time', 'south_north', 'west_east')
# T2: TEMP at 2 M ('Time', 'south_north', 'west_east')
# TH2: POT TEMP at 2 M ('Time', 'south_north', 'west_east')
# PSFC: SFC PRESSURE ('Time', 'south_north', 'west_east')
# U10: U at 10 M ('Time', 'south_north', 'west_east')
# V10: V at 10 M ('Time', 'south_north', 'west_east')
# RDX: INVERSE X GRID LENGTH ('Time',)
# RDY: INVERSE Y GRID LENGTH ('Time',)
# DTS: SMALL TIMESTEP ('Time',)
# DTSEPS: TIME WEIGHT CONSTANT FOR SMALL STEPS ('Time',)
# RESM: TIME WEIGHT CONSTANT FOR SMALL STEPS ('Time',)
# ZETATOP: ZETA AT MODEL TOP ('Time',)
# CF1: 2nd order extrapolation constant ('Time',)
# CF2: 2nd order extrapolation constant ('Time',)
# CF3: 2nd order extrapolation constant ('Time',)
# QVAPOR: Water vapor mixing ratio ('Time', 'bottom_top', 'south_north', 'west_east')
# QCLOUD: Cloud water mixing ratio ('Time', 'bottom_top', 'south_north', 'west_east')
# QRAIN: Rain water mixing ratio ('Time', 'bottom_top', 'south_north', 'west_east')
# QICE: Ice mixing ratio ('Time', 'bottom_top', 'south_north', 'west_east')
# QSNOW: Snow mixing ratio ('Time', 'bottom_top', 'south_north', 'west_east')
# QGRAUP: Graupel mixing ratio ('Time', 'bottom_top', 'south_north', 'west_east')
# QNICE: Ice Number concentration ('Time', 'bottom_top', 'south_north', 'west_east')
# QNRAIN: Rain Number concentration ('Time', 'bottom_top', 'south_north', 'west_east')
# qke_adv: twice TKE from MYNN ('Time', 'bottom_top', 'south_north', 'west_east')
# FCX: RELAXATION TERM FOR BOUNDARY ZONE ('Time', 'DIM0010')
# GCX: 2ND RELAXATION TERM FOR BOUNDARY ZONE ('Time', 'DIM0010')
# TOPOSLPX: ELEVATION X SLOPE ('Time', 'south_north', 'west_east')
# TOPOSLPY: ELEVATION Y SLOPE ('Time', 'south_north', 'west_east')
# SHDMAX: ANNUAL MAX VEG FRACTION ('Time', 'south_north', 'west_east')
# SHDMIN: ANNUAL MIN VEG FRACTION ('Time', 'south_north', 'west_east')
# SHDAVG: ANNUAL AVG VEG FRACTION ('Time', 'south_north', 'west_east')
# SNOALB: ANNUAL MAX SNOW ALBEDO IN FRACTION ('Time', 'south_north', 'west_east')
# LANDUSEF: LANDUSE FRACTION BY CATEGORY ('Time', 'land_cat_stag', 'south_north', 'west_east')
# SOILCTOP: SOIL CAT FRACTION (TOP) ('Time', 'soil_cat_stag', 'south_north', 'west_east')
# SOILCBOT: SOIL CAT FRACTION (BOTTOM) ('Time', 'soil_cat_stag', 'south_north', 'west_east')
# TSLB: SOIL TEMPERATURE ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# BUILD_AREA_FRACTION: BUILDING PLAN AREA DENSITY ('Time', 'south_north', 'west_east')
# BUILD_SURF_RATIO: BUILDING SURFACE AREA TO PLAN AREA RATIO ('Time', 'south_north', 'west_east')
# BUILD_HEIGHT: AVERAGE BUILDING HEIGHT WEIGHTED BY BUILDING PLAN AREA ('Time', 'south_north', 'west_east')
# MH_URB2D: Mean Building Height ('Time', 'south_north', 'west_east')
# STDH_URB2D: Standard Deviation of Building Height ('Time', 'south_north', 'west_east')
# LF_URB2D: Frontal Area Index ('Time', 'urban_wind_directions_stag', 'south_north', 'west_east')
# Z0_URB2D: Roughness length for momentum ('Time', 'south_north', 'west_east')
# LF_URB2D_S: Frontal area index (no wind directional dependency) ('Time', 'south_north', 'west_east')
# AHE: Anthropogenic heat emission ('Time', 'month_hour', 'south_north', 'west_east')
# SMOIS: SOIL MOISTURE ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# SH2O: SOIL LIQUID WATER ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# SMCREL: RELATIVE SOIL MOISTURE ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# SEAICE: SEA ICE FLAG ('Time', 'south_north', 'west_east')
# IVGTYP: DOMINANT VEGETATION CATEGORY ('Time', 'south_north', 'west_east')
# ISLTYP: DOMINANT SOIL CATEGORY ('Time', 'south_north', 'west_east')
# VEGFRA: VEGETATION FRACTION ('Time', 'south_north', 'west_east')
# SNOW: SNOW WATER EQUIVALENT ('Time', 'south_north', 'west_east')
# SNOWH: PHYSICAL SNOW DEPTH ('Time', 'south_north', 'west_east')
# CANWAT: CANOPY WATER ('Time', 'south_north', 'west_east')
# FNDSNOWH: SNOWH_LOGICAL ('Time',)
# FNDSOILW: SOILW_LOGICAL ('Time',)
# FNDALBSI: ALBSI_LOGICAL ('Time',)
# FNDSNOWSI: SNOWSI_LOGICAL ('Time',)
# FNDICEDEPTH: ICEDEPTH_LOGICAL ('Time',)
# LAKE_DEPTH: lake depth ('Time', 'south_north', 'west_east')
# WATER_DEPTH: global water depth ('Time', 'south_north', 'west_east')
# UOCE: SEA SURFACE ZONAL CURRENTS ('Time', 'south_north', 'west_east')
# VOCE: SEA SURFACE MERIDIONAL CURRENTS ('Time', 'south_north', 'west_east')
# FRC_URB2D: URBAN FRACTION ('Time', 'south_north', 'west_east')
# LAI: LEAF AREA INDEX ('Time', 'south_north', 'west_east')
# QKE: twice TKE from MYNN ('Time', 'bottom_top', 'south_north', 'west_east')
# VAR: STANDARD DEVIATION OF SUBGRID-SCALE OROGRAPHY ('Time', 'south_north', 'west_east')
# CON: OROGRAPHIC CONVEXITY ('Time', 'south_north', 'west_east')
# OA1: ASYMMETRY OF SUBGRID-SCALE OROGRAPHY FOR WESTERLY FLOW ('Time', 'south_north', 'west_east')
# OA2: ASYMMETRY OF SUBGRID-SCALE OROGRAPHY FOR SOUTHERLY FLOW ('Time', 'south_north', 'west_east')
# OA3: ASYMMETRY OF SUBGRID-SCALE OROGRAPHY FOR SOUTH-WESTERLY FLOW ('Time', 'south_north', 'west_east')
# OA4: ASYMMETRY OF SUBGRID-SCALE OROGRAPHY FOR NORTH-WESTERLY FLOW ('Time', 'south_north', 'west_east')
# OL1: NON-DIMENSIONAL EFFECTIVE OROGRAPHIC LENGTH FOR WESTERLY FLOW ('Time', 'south_north', 'west_east')
# OL2: NON-DIMENSIONAL EFFECTIVE OROGRAPHIC LENGTH FOR SOUTHERLY FLOW ('Time', 'south_north', 'west_east')
# OL3: NON-DIMENSIONAL EFFECTIVE OROGRAPHIC LENGTH FOR SOUTH-WESTERLY FLOW ('Time', 'south_north', 'west_east')
# OL4: NON-DIMENSIONAL EFFECTIVE OROGRAPHIC LENGTH FOR NORTH-WESTERLY FLOW ('Time', 'south_north', 'west_east')
# O3_GFS_DU: Total ozone from GFS ('Time', 'south_north', 'west_east')
# MAPFAC_M: Map scale factor on mass grid ('Time', 'south_north', 'west_east')
# MAPFAC_U: Map scale factor on u-grid ('Time', 'south_north', 'west_east_stag')
# MAPFAC_V: Map scale factor on v-grid ('Time', 'south_north_stag', 'west_east')
# MAPFAC_MX: Map scale factor on mass grid, x direction ('Time', 'south_north', 'west_east')
# MAPFAC_MY: Map scale factor on mass grid, y direction ('Time', 'south_north', 'west_east')
# MAPFAC_UX: Map scale factor on u-grid, x direction ('Time', 'south_north', 'west_east_stag')
# MAPFAC_UY: Map scale factor on u-grid, y direction ('Time', 'south_north', 'west_east_stag')
# MAPFAC_VX: Map scale factor on v-grid, x direction ('Time', 'south_north_stag', 'west_east')
# MF_VX_INV: Inverse map scale factor on v-grid, x direction ('Time', 'south_north_stag', 'west_east')
# MAPFAC_VY: Map scale factor on v-grid, y direction ('Time', 'south_north_stag', 'west_east')
# F: Coriolis sine latitude term ('Time', 'south_north', 'west_east')
# E: Coriolis cosine latitude term ('Time', 'south_north', 'west_east')
# SINALPHA: Local sine of map rotation ('Time', 'south_north', 'west_east')
# COSALPHA: Local cosine of map rotation ('Time', 'south_north', 'west_east')
# HGT: Terrain Height ('Time', 'south_north', 'west_east')
# TSK: SURFACE SKIN TEMPERATURE ('Time', 'south_north', 'west_east')
# U_BASE: BASE STATE X WIND IN IDEALIZED CASES ('Time', 'bottom_top')
# V_BASE: BASE STATE Y WIND IN IDEALIZED CASES ('Time', 'bottom_top')
# QV_BASE: BASE STATE QV IN IDEALIZED CASES ('Time', 'bottom_top')
# Z_BASE: BASE STATE HEIGHT IN IDEALIZED CASES ('Time', 'bottom_top')
# U_FRAME: FRAME X WIND ('Time',)
# V_FRAME: FRAME Y WIND ('Time',)
# P_TOP: PRESSURE TOP OF THE MODEL ('Time',)
# GOT_VAR_SSO: whether VAR_SSO was included in WPS output (beginning V3.4) ('Time',)
# LAT_LL_T: latitude lower left, temp point ('Time',)
# LAT_UL_T: latitude up left, temp point ('Time',)
# LAT_UR_T: latitude up right, temp point ('Time',)
# LAT_LR_T: latitude lower right, temp point ('Time',)
# LAT_LL_U: latitude lower left, u point ('Time',)
# LAT_UL_U: latitude up left, u point ('Time',)
# LAT_UR_U: latitude up right, u point ('Time',)
# LAT_LR_U: latitude lower right, u point ('Time',)
# LAT_LL_V: latitude lower left, v point ('Time',)
# LAT_UL_V: latitude up left, v point ('Time',)
# LAT_UR_V: latitude up right, v point ('Time',)
# LAT_LR_V: latitude lower right, v point ('Time',)
# LAT_LL_D: latitude lower left, massless point ('Time',)
# LAT_UL_D: latitude up left, massless point ('Time',)
# LAT_UR_D: latitude up right, massless point ('Time',)
# LAT_LR_D: latitude lower right, massless point ('Time',)
# LON_LL_T: longitude lower left, temp point ('Time',)
# LON_UL_T: longitude up left, temp point ('Time',)
# LON_UR_T: longitude up right, temp point ('Time',)
# LON_LR_T: longitude lower right, temp point ('Time',)
# LON_LL_U: longitude lower left, u point ('Time',)
# LON_UL_U: longitude up left, u point ('Time',)
# LON_UR_U: longitude up right, u point ('Time',)
# LON_LR_U: longitude lower right, u point ('Time',)
# LON_LL_V: longitude lower left, v point ('Time',)
# LON_UL_V: longitude up left, v point ('Time',)
# LON_UR_V: longitude up right, v point ('Time',)
# LON_LR_V: longitude lower right, v point ('Time',)
# LON_LL_D: longitude lower left, massless point ('Time',)
# LON_UL_D: longitude up left, massless point ('Time',)
# LON_UR_D: longitude up right, massless point ('Time',)
# LON_LR_D: longitude lower right, massless point ('Time',)
# T00: BASE STATE TEMPERATURE ('Time',)
# P00: BASE STATE PRESSURE ('Time',)
# TLP: BASE STATE LAPSE RATE ('Time',)
# TISO: TEMP AT WHICH THE BASE T TURNS CONST ('Time',)
# TLP_STRAT: BASE STATE LAPSE RATE (DT/D(LN(P)) IN STRATOSPHERE ('Time',)
# P_STRAT: BASE STATE PRESSURE AT BOTTOM OF STRATOSPHERE ('Time',)
# CLDFRA: CLOUD FRACTION ('Time', 'bottom_top', 'south_north', 'west_east')
# XLAT_U: LATITUDE, SOUTH IS NEGATIVE ('Time', 'south_north', 'west_east_stag')
# XLONG_U: LONGITUDE, WEST IS NEGATIVE ('Time', 'south_north', 'west_east_stag')
# XLAT_V: LATITUDE, SOUTH IS NEGATIVE ('Time', 'south_north_stag', 'west_east')
# XLONG_V: LONGITUDE, WEST IS NEGATIVE ('Time', 'south_north_stag', 'west_east')
# CLAT: COMPUTATIONAL GRID LATITUDE, SOUTH IS NEGATIVE ('Time', 'south_north', 'west_east')
# ALBBCK: BACKGROUND ALBEDO ('Time', 'south_north', 'west_east')
# TSK_MOSAIC: vegetation temperature ('Time', 'mosaic', 'south_north', 'west_east')
# QSFC_MOSAIC: SPECIFIC HUMIDITY AT LOWER BOUNDARY ('Time', 'mosaic', 'south_north', 'west_east')
# TSLB_MOSAIC: SOIL TEMPERATURE ('Time', 'mosaic_stag', 'south_north', 'west_east')
# SMOIS_MOSAIC: SOIL MOISTURE ('Time', 'mosaic_stag', 'south_north', 'west_east')
# SH2O_MOSAIC: SOIL LIQUID WATER ('Time', 'mosaic_stag', 'south_north', 'west_east')
# CANWAT_MOSAIC: CANOPY WATER ('Time', 'mosaic', 'south_north', 'west_east')
# SNOW_MOSAIC: SNOW WATER EQUIVALENT ('Time', 'mosaic', 'south_north', 'west_east')
# SNOWH_MOSAIC: PHYSICAL SNOW DEPTH ('Time', 'mosaic', 'south_north', 'west_east')
# SNOWC_MOSAIC: FLAG INDICATING SNOW COVERAGE (1 FOR SNOW COVER) ('Time', 'mosaic', 'south_north', 'west_east')
# MOSAIC_CAT_INDEX:  ('Time', 'land_cat_stag', 'south_north', 'west_east')
# LANDUSEF2: sorted landuse fraction ('Time', 'land_cat_stag', 'south_north', 'west_east')
# TMN: SOIL TEMPERATURE AT LOWER BOUNDARY ('Time', 'south_north', 'west_east')
# XLAND: LAND MASK (1 FOR LAND, 2 FOR WATER) ('Time', 'south_north', 'west_east')
# CPLMASK: COUPLING MASK (0:VALUE FROM SST UPDATE; 1:VALUE FROM COUPLED OCEAN), vertical di ('Time', 'num_ext_model_couple_dom_stag', 'south_north', 'west_east')
# SNOWC: FLAG INDICATING SNOW COVERAGE (1 FOR SNOW COVER) ('Time', 'south_north', 'west_east')
# SR: fraction of frozen precipitation ('Time', 'south_north', 'west_east')
# SAVE_TOPO_FROM_REAL: 1=original topo from real/0=topo modified by WRF ('Time',)
# LAKEFLAG: Flag for lake  in the global attributes for metgrid data ('Time',)
# LAKE_DEPTH_FLAG: Flag for lakedepth  in the global attributes for metgrid data ('Time',)
# C1H: half levels, c1h = d bf / d eta, using znw ('Time', 'bottom_top')
# C2H: half levels, c2h = (1-c1h)*(p0-pt) ('Time', 'bottom_top')
# C1F: full levels, c1f = d bf / d eta, using znu ('Time', 'bottom_top_stag')
# C2F: full levels, c2f = (1-c1f)*(p0-pt) ('Time', 'bottom_top_stag')
# C3H: half levels, c3h = bh ('Time', 'bottom_top')
# C4H: half levels, c4h = (eta-bh)*(p0-pt), using znu ('Time', 'bottom_top')
# C3F: full levels, c3f = bf ('Time', 'bottom_top_stag')
# C4F: full levels, c4f = (eta-bf)*(p0-pt), using znw ('Time', 'bottom_top_stag')
# PCB: base state dry air mass in column ('Time', 'south_north', 'west_east')
# PC: perturbation dry air mass in column ('Time', 'south_north', 'west_east')
# LANDMASK: LAND MASK (1 FOR LAND, 0 FOR WATER) ('Time', 'south_north', 'west_east')
# LAKEMASK: LAKE MASK (1 FOR LAKE, 0 FOR NON-LAKE) ('Time', 'south_north', 'west_east')
# SST: SEA SURFACE TEMPERATURE ('Time', 'south_north', 'west_east')

# %%
def plot_all_vars(dataset: Dataset) -> None:
    cols_num, len_vars = 10, len(dataset.variables)
    _, axes = plt.subplots(math.ceil(len_vars / cols_num), cols_num, figsize=(12, 26))
    idx: int = 0
    for var in dataset.variables.values():
        i, j = idx // cols_num, idx % cols_num
        axes[i][j].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
        axes[i][j].set_title(var.name, x=0.5, y=0.35, fontweight="500", fontsize=6)
        if j != 0: axes[i][j].set_yticklabels([])
        if i != 0: axes[i][j].set_xticklabels([])
        if len(var.shape) == 3: axes[i][j].contourf(var[0], cmap='Spectral')
        elif len(var.shape) == 4: axes[i][j].contourf(var[0][0], cmap='Spectral')
        else: continue
        idx += 1

if not is_py:
    plot_all_vars(dataset)

# %%
import numpy as np

def modify_convert_uniform(src: Dataset, var_names: list[str]) -> Dataset:
    '''
    Convert all variables in the src file to uniform average
    src         source dataset
    var_names   list of variable names to average
    '''

    for var_name in var_names:
        print(f'Averaging {var_name}...', end='\r')
        modified_var, var_shape = src.variables[var_name][:], src.variables[var_name].shape
        if len(var_shape) == 3:
            for timestep in range(var_shape[0]):
                average_value = np.mean(src.variables[var_name][timestep])
                modified_var[timestep][:] = average_value
        elif len(var_shape) == 4:
            for timestep in range(var_shape[0]):
                for height in range(var_shape[1]):
                    average_value = np.mean(src.variables[var_name][timestep][height])
                    modified_var[timestep][height][:] = average_value

        src.variables[var_name][:] = modified_var

    return src

# %%
def modify_water_depth(src: Dataset) -> Dataset:
    modified_water_depth = src.variables['WATER_DEPTH'][:]
    modified_water_depth[0][:, :] = -10.0
    src.variables['WATER_DEPTH'][:] = modified_water_depth

    return src

# %%
def modify_remove_initial_wind(src: Dataset) -> Dataset:
    src.variables['U'][:] = np.zeros(src.variables['U'].shape)
    src.variables['U10'][:] = np.zeros(src.variables['U10'].shape)

    src.variables['V'][:] = np.zeros(src.variables['V'].shape)
    src.variables['V10'][:] = np.zeros(src.variables['V10'].shape)

    src.variables['W'][:] = np.zeros(src.variables['W'].shape)

    return src

# %%
def modify_random_initial_winds(src: Dataset) -> Dataset:
    dimensions_u = src.variables['U'].shape
    src.variables['U'][:] = (np.random.rand(*dimensions_u) * 0.2) - 0.1

    dimensions_v = src.variables['V'].shape
    src.variables['V'][:] = (np.random.rand(*dimensions_v) * 0.2) - 0.1

    return src

# %%
def modify_remove_sin_cos_alpha(src: Dataset) -> Dataset:
    src.variables['SINALPHA'][:] = 0
    src.variables['COSALPHA'][:] = 0
    src.variables['E'][:] = 0

    return src

# %%
def modify_reduce_vapor(src: Dataset) -> Dataset:
    src.variables['QVAPOR'][:] *= 0.01
    return src

# %%
def modify_urban_params(src: Dataset) -> Dataset:
    attrs = src.__dict__
    mask = src.variables['LU_INDEX'][0][:] == attrs['ISURBAN']
    urban_vars = {
        'BUILD_SURF_RATIO': 0.25,
        'BUILD_HEIGHT': 1,
        'STDH_URB2D': 0.5,
        'LF_URB2D': 0.25,
    }
    for name, value in urban_vars.items():
        if name == 'LF_URB2D':
            continue
        src.variables[name][0][mask] = value

    for i in range(3):
        src.variables['LF_URB2D'][0][i][mask] = urban_vars['LF_URB2D']
    return src

#%%

import os

file_name: str = 'wrfinput_d01'
output_name: str = root_dir + 'modified-files/' + file_name

if len(glob(output_name)) > 0:
    os.remove(output_name)

with Dataset(all_files[0], 'r', format='NETCDF4') as src:
    with Dataset(output_name, 'w', format='NETCDF4') as out:
        # Get the attributes of the original file
        attributes = src.__dict__

        # Add extra field to attrs, e.g. notes
        attributes['TITLE'] += ' (MODIFIED)'
        attributes['NOTE'] = 'Idealized land-water split by Mok'

        # Set it into the output
        out.setncatts(attributes)

        # Copy dimensions
        for name, dimension in src.dimensions.items():
            dimension_size = (
                len(dimension) if not dimension.isunlimited() else None
            ) # The value should be None for unlimited dimension

            # Create the dimension with its size, make sure to modify it
            # if you changed the variable dimension
            out.createDimension(name, dimension_size)

        # Modify the variable, see function on the cell above

        for name, variable in src.variables.items():
            out.createVariable(
                name,
                variable.datatype,
                variable.dimensions,
                zlib = True,            # Lossless compression (optional)
                complevel = 5,          # Lossless compression (optional)
                shuffle = True          # Lossless compression (optional)
            )

            # Set output variable attributes
            out[name].setncatts(src[name].__dict__)
            out[name][:] = src[name][:]

        # out = modify_water_depth(out)
        out = modify_remove_initial_wind(out)
        # out = modify_random_initial_winds(out)
        out = modify_remove_sin_cos_alpha(out)
        # out = modify_reduce_vapor(out)
        out = modify_urban_params(out)

        var_names = [ 'T', 'THM', 'MU', 'P', 'AL', 'P_HYD', 'Q2', 'T2', 'TH2',
            'PSFC', 'QVAPOR', 'TSLB', 'TMN', 'TSK', 'SST', 'VAR',
            'CON', 'VAR_SSO', 'OA1', 'OA2', 'OA3', 'OA4',
            'OL1', 'OL2', 'OL3', 'OL4',
        ]
        out = modify_convert_uniform(out, var_names)

    print('Done! Congrats 🎉')
# Out:
# Done! Congrats 🎉...

# %%
import subprocess

if is_py:
    subprocess.call(['mv', output_name, all_files[0]])
else:
    # Test reading output file
    out_dataset = Dataset(output_name)
    plot_all_vars(out_dataset)
