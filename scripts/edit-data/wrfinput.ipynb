# %%
from netCDF4 import Dataset
from glob import glob
import sys, os

is_py = os.path.basename(sys.argv[0]) == 'wrfinput.ju.py'
RUN_ID = int(sys.argv[1]) if is_py and len(sys.argv) > 1 else 45

root_dir = '/home/guc/'
data_dir = f'runs/{RUN_ID:03}*/'
root_data_dir = glob(root_dir + data_dir)[0]

all_files = glob(root_data_dir + 'wrfinput*')

# %%
def list_landuse(dataset: Dataset) -> None:
    attrs = dataset.__dict__
    print(f'Land use category (MMINLU), check with WRF/LANDUSE.TBL: {attrs['MMINLU']}')
    print(f'Land use category number (NUM_LAND_CAT): {attrs['NUM_LAND_CAT']}')
    print(f'Water type index (ISWATER): {attrs['ISWATER']}')
    print(f'Urban type index (ISWATER): {attrs['ISURBAN']}')

# show_lu()
# list_landuse()

# %%
import matplotlib.pyplot as plt
import math

def list_variables(dataset: Dataset) -> None:
    '''
    List all variables in the nc dataset for adjustment
    dataset:    netcdf dataset
    '''
    print('\n'.join(map(lambda x: f'{x.name}: {dataset[x.name].__dict__.get('description')} {x.dimensions}', dataset.variables.values())))

dataset = Dataset(all_files[0], format="NETCDF4")
list_variables(dataset)
# Out:
# Times: None ('Time', 'DateStrLen')
# XLAT: degree_north ('Time', 'south_north', 'west_east')
# XLONG: degree_east ('Time', 'south_north', 'west_east')
# LU_INDEX:  ('Time', 'south_north', 'west_east')
# ZNU:  ('Time', 'bottom_top')
# ZNW:  ('Time', 'bottom_top_stag')
# ZS: m ('Time', 'soil_layers_stag')
# DZS: m ('Time', 'soil_layers_stag')
# VAR_SSO: m2 ('Time', 'south_north', 'west_east')
# EROD: none ('Time', 'dust_erosion_dimension', 'south_north', 'west_east')
# BATHYMETRY_FLAG: - ('Time',)
# U: m s-1 ('Time', 'bottom_top', 'south_north', 'west_east_stag')
# V: m s-1 ('Time', 'bottom_top', 'south_north_stag', 'west_east')
# W: m s-1 ('Time', 'bottom_top_stag', 'south_north', 'west_east')
# PH: m2 s-2 ('Time', 'bottom_top_stag', 'south_north', 'west_east')
# PHB: m2 s-2 ('Time', 'bottom_top_stag', 'south_north', 'west_east')
# T: K ('Time', 'bottom_top', 'south_north', 'west_east')
# THM: K ('Time', 'bottom_top', 'south_north', 'west_east')
# T_INIT: K ('Time', 'bottom_top', 'south_north', 'west_east')
# MU: Pa ('Time', 'south_north', 'west_east')
# MUB: Pa ('Time', 'south_north', 'west_east')
# P: Pa ('Time', 'bottom_top', 'south_north', 'west_east')
# AL: m3 kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# ALB: m3 kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# PB: Pa ('Time', 'bottom_top', 'south_north', 'west_east')
# FNM:  ('Time', 'bottom_top')
# FNP:  ('Time', 'bottom_top')
# RDNW:  ('Time', 'bottom_top')
# RDN:  ('Time', 'bottom_top')
# DNW:  ('Time', 'bottom_top')
# DN:  ('Time', 'bottom_top')
# T_BASE: K ('Time', 'bottom_top')
# CFN:  ('Time',)
# CFN1:  ('Time',)
# STEP_NUMBER: - ('Time',)
# THIS_IS_AN_IDEAL_RUN: - ('Time',)
# P_HYD: Pa ('Time', 'bottom_top', 'south_north', 'west_east')
# Q2: kg kg-1 ('Time', 'south_north', 'west_east')
# T2: K ('Time', 'south_north', 'west_east')
# TH2: K ('Time', 'south_north', 'west_east')
# PSFC: Pa ('Time', 'south_north', 'west_east')
# U10: m s-1 ('Time', 'south_north', 'west_east')
# V10: m s-1 ('Time', 'south_north', 'west_east')
# RDX: m-1 ('Time',)
# RDY: m-1 ('Time',)
# DTS:  ('Time',)
# DTSEPS:  ('Time',)
# RESM:  ('Time',)
# ZETATOP:  ('Time',)
# CF1:  ('Time',)
# CF2:  ('Time',)
# CF3:  ('Time',)
# QVAPOR: kg kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# QCLOUD: kg kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# QRAIN: kg kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# QICE: kg kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# QSNOW: kg kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# QGRAUP: kg kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# QNICE:   kg-1 ('Time', 'bottom_top', 'south_north', 'west_east')
# QNRAIN:   kg(-1) ('Time', 'bottom_top', 'south_north', 'west_east')
# qke_adv: m2 s-2 ('Time', 'bottom_top', 'south_north', 'west_east')
# FCX:  ('Time', 'DIM0010')
# GCX:  ('Time', 'DIM0010')
# TOPOSLPX:  ('Time', 'south_north', 'west_east')
# TOPOSLPY:  ('Time', 'south_north', 'west_east')
# SHDMAX:  ('Time', 'south_north', 'west_east')
# SHDMIN:  ('Time', 'south_north', 'west_east')
# SHDAVG:  ('Time', 'south_north', 'west_east')
# SNOALB:  ('Time', 'south_north', 'west_east')
# LANDUSEF:  ('Time', 'land_cat_stag', 'south_north', 'west_east')
# SOILCTOP:  ('Time', 'soil_cat_stag', 'south_north', 'west_east')
# SOILCBOT:  ('Time', 'soil_cat_stag', 'south_north', 'west_east')
# TSLB: K ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# BUILD_AREA_FRACTION: dimensionless ('Time', 'south_north', 'west_east')
# BUILD_SURF_RATIO: dimensionless ('Time', 'south_north', 'west_east')
# BUILD_HEIGHT: m ('Time', 'south_north', 'west_east')
# MH_URB2D: m ('Time', 'south_north', 'west_east')
# STDH_URB2D: m2 ('Time', 'south_north', 'west_east')
# LF_URB2D: dimensionless ('Time', 'urban_wind_directions_stag', 'south_north', 'west_east')
# Z0_URB2D: m ('Time', 'south_north', 'west_east')
# LF_URB2D_S:  ('Time', 'south_north', 'west_east')
# AHE: W m-2 ('Time', 'month_hour', 'south_north', 'west_east')
# SMOIS: m3 m-3 ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# SH2O: m3 m-3 ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# SMCREL:  ('Time', 'soil_layers_stag', 'south_north', 'west_east')
# SEAICE:  ('Time', 'south_north', 'west_east')
# IVGTYP:  ('Time', 'south_north', 'west_east')
# ISLTYP:  ('Time', 'south_north', 'west_east')
# VEGFRA:  ('Time', 'south_north', 'west_east')
# SNOW: kg m-2 ('Time', 'south_north', 'west_east')
# SNOWH: m ('Time', 'south_north', 'west_east')
# CANWAT: kg m-2 ('Time', 'south_north', 'west_east')
# FNDSNOWH: - ('Time',)
# FNDSOILW: - ('Time',)
# FNDALBSI: - ('Time',)
# FNDSNOWSI: - ('Time',)
# FNDICEDEPTH: - ('Time',)
# LAKE_DEPTH: m ('Time', 'south_north', 'west_east')
# WATER_DEPTH: m ('Time', 'south_north', 'west_east')
# UOCE: m s-1 ('Time', 'south_north', 'west_east')
# VOCE: m s-1 ('Time', 'south_north', 'west_east')
# FRC_URB2D: dimensionless ('Time', 'south_north', 'west_east')
# LAI: m-2/m-2 ('Time', 'south_north', 'west_east')
# QKE: m2 s-2 ('Time', 'bottom_top', 'south_north', 'west_east')
# VAR: m ('Time', 'south_north', 'west_east')
# CON:  ('Time', 'south_north', 'west_east')
# OA1:  ('Time', 'south_north', 'west_east')
# OA2:  ('Time', 'south_north', 'west_east')
# OA3:  ('Time', 'south_north', 'west_east')
# OA4:  ('Time', 'south_north', 'west_east')
# OL1:  ('Time', 'south_north', 'west_east')
# OL2:  ('Time', 'south_north', 'west_east')
# OL3:  ('Time', 'south_north', 'west_east')
# OL4:  ('Time', 'south_north', 'west_east')
# O3_GFS_DU: Dobson Units ('Time', 'south_north', 'west_east')
# MAPFAC_M:  ('Time', 'south_north', 'west_east')
# MAPFAC_U:  ('Time', 'south_north', 'west_east_stag')
# MAPFAC_V:  ('Time', 'south_north_stag', 'west_east')
# MAPFAC_MX:  ('Time', 'south_north', 'west_east')
# MAPFAC_MY:  ('Time', 'south_north', 'west_east')
# MAPFAC_UX:  ('Time', 'south_north', 'west_east_stag')
# MAPFAC_UY:  ('Time', 'south_north', 'west_east_stag')
# MAPFAC_VX:  ('Time', 'south_north_stag', 'west_east')
# MF_VX_INV:  ('Time', 'south_north_stag', 'west_east')
# MAPFAC_VY:  ('Time', 'south_north_stag', 'west_east')
# F: s-1 ('Time', 'south_north', 'west_east')
# E: s-1 ('Time', 'south_north', 'west_east')
# SINALPHA:  ('Time', 'south_north', 'west_east')
# COSALPHA:  ('Time', 'south_north', 'west_east')
# HGT: m ('Time', 'south_north', 'west_east')
# TSK: K ('Time', 'south_north', 'west_east')
# U_BASE:  ('Time', 'bottom_top')
# V_BASE:  ('Time', 'bottom_top')
# QV_BASE:  ('Time', 'bottom_top')
# Z_BASE:  ('Time', 'bottom_top')
# U_FRAME: m s-1 ('Time',)
# V_FRAME: m s-1 ('Time',)
# P_TOP: Pa ('Time',)
# GOT_VAR_SSO:  ('Time',)
# LAT_LL_T: degrees ('Time',)
# LAT_UL_T: degrees ('Time',)
# LAT_UR_T: degrees ('Time',)
# LAT_LR_T: degrees ('Time',)
# LAT_LL_U: degrees ('Time',)
# LAT_UL_U: degrees ('Time',)
# LAT_UR_U: degrees ('Time',)
# LAT_LR_U: degrees ('Time',)
# LAT_LL_V: degrees ('Time',)
# LAT_UL_V: degrees ('Time',)
# LAT_UR_V: degrees ('Time',)
# LAT_LR_V: degrees ('Time',)
# LAT_LL_D: degrees ('Time',)
# LAT_UL_D: degrees ('Time',)
# LAT_UR_D: degrees ('Time',)
# LAT_LR_D: degrees ('Time',)
# LON_LL_T: degrees ('Time',)
# LON_UL_T: degrees ('Time',)
# LON_UR_T: degrees ('Time',)
# LON_LR_T: degrees ('Time',)
# LON_LL_U: degrees ('Time',)
# LON_UL_U: degrees ('Time',)
# LON_UR_U: degrees ('Time',)
# LON_LR_U: degrees ('Time',)
# LON_LL_V: degrees ('Time',)
# LON_UL_V: degrees ('Time',)
# LON_UR_V: degrees ('Time',)
# LON_LR_V: degrees ('Time',)
# LON_LL_D: degrees ('Time',)
# LON_UL_D: degrees ('Time',)
# LON_UR_D: degrees ('Time',)
# LON_LR_D: degrees ('Time',)
# T00: K ('Time',)
# P00: Pa ('Time',)
# TLP:  ('Time',)
# TISO: K ('Time',)
# TLP_STRAT: K ('Time',)
# P_STRAT: Pa ('Time',)
# CLDFRA:  ('Time', 'bottom_top', 'south_north', 'west_east')
# XLAT_U: degree_north ('Time', 'south_north', 'west_east_stag')
# XLONG_U: degree_east ('Time', 'south_north', 'west_east_stag')
# XLAT_V: degree_north ('Time', 'south_north_stag', 'west_east')
# XLONG_V: degree_east ('Time', 'south_north_stag', 'west_east')
# CLAT: degree_north ('Time', 'south_north', 'west_east')
# ALBBCK:  ('Time', 'south_north', 'west_east')
# TSK_MOSAIC: K ('Time', 'mosaic', 'south_north', 'west_east')
# QSFC_MOSAIC:  ('Time', 'mosaic', 'south_north', 'west_east')
# TSLB_MOSAIC: K ('Time', 'mosaic_stag', 'south_north', 'west_east')
# SMOIS_MOSAIC: m3 m-3 ('Time', 'mosaic_stag', 'south_north', 'west_east')
# SH2O_MOSAIC: m3 m-3 ('Time', 'mosaic_stag', 'south_north', 'west_east')
# CANWAT_MOSAIC: kg m-2 ('Time', 'mosaic', 'south_north', 'west_east')
# SNOW_MOSAIC: kg m-2 ('Time', 'mosaic', 'south_north', 'west_east')
# SNOWH_MOSAIC: m ('Time', 'mosaic', 'south_north', 'west_east')
# SNOWC_MOSAIC:  ('Time', 'mosaic', 'south_north', 'west_east')
# MOSAIC_CAT_INDEX:  ('Time', 'land_cat_stag', 'south_north', 'west_east')
# LANDUSEF2:  ('Time', 'land_cat_stag', 'south_north', 'west_east')
# TMN: K ('Time', 'south_north', 'west_east')
# XLAND:  ('Time', 'south_north', 'west_east')
# CPLMASK:  ('Time', 'num_ext_model_couple_dom_stag', 'south_north', 'west_east')
# SNOWC:  ('Time', 'south_north', 'west_east')
# SR: - ('Time', 'south_north', 'west_east')
# SAVE_TOPO_FROM_REAL: flag ('Time',)
# LAKEFLAG: - ('Time',)
# LAKE_DEPTH_FLAG: - ('Time',)
# C1H: Dimensionless ('Time', 'bottom_top')
# C2H: Pa ('Time', 'bottom_top')
# C1F: Dimensionless ('Time', 'bottom_top_stag')
# C2F: Pa ('Time', 'bottom_top_stag')
# C3H: Dimensionless ('Time', 'bottom_top')
# C4H: Pa ('Time', 'bottom_top')
# C3F: Dimensionless ('Time', 'bottom_top_stag')
# C4F: Pa ('Time', 'bottom_top_stag')
# PCB: Pa ('Time', 'south_north', 'west_east')
# PC: Pa ('Time', 'south_north', 'west_east')
# LANDMASK:  ('Time', 'south_north', 'west_east')
# LAKEMASK:  ('Time', 'south_north', 'west_east')
# SST: K ('Time', 'south_north', 'west_east')

# %%
def plot_all_vars(dataset: Dataset) -> None:
    cols_num, len_vars = 10, len(dataset.variables)
    _, axes = plt.subplots(math.ceil(len_vars / cols_num), cols_num, figsize=(12, 26))
    idx: int = 0
    for var in dataset.variables.values():
        i, j = idx // cols_num, idx % cols_num
        axes[i][j].tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
        axes[i][j].set_title(var.name, x=0.5, y=0.35, fontweight="500", fontsize=6)
        if j != 0: axes[i][j].set_yticklabels([])
        if i != 0: axes[i][j].set_xticklabels([])
        if len(var.shape) == 3: axes[i][j].contourf(var[0], cmap='Spectral')
        elif len(var.shape) == 4: axes[i][j].contourf(var[0][0], cmap='Spectral')
        else: continue
        idx += 1

if not is_py:
    plot_all_vars(dataset)
# Out:
# [[[9.3517685 9.3517685 9.3517685 ... 9.3517685 9.3517685 9.3517685]
#   [9.3517685 9.3517685 9.3517685 ... 9.3517685 9.3517685 9.3517685]
#   [9.3517685 9.3517685 9.3517685 ... 9.3517685 9.3517685 9.3517685]
#   ...
#   [9.3517685 9.3517685 9.3517685 ... 9.3517685 9.3517685 9.3517685]
#   [9.3517685 9.3517685 9.3517685 ... 9.3517685 9.3517685 9.3517685]
#   [9.3517685 9.3517685 9.3517685 ... 9.3517685 9.3517685 9.3517685]]]

# %%
import numpy as np

def modify_convert_uniform(src: Dataset, var_names: list[str]) -> Dataset:
    '''
    Convert all variables in the src file to uniform average
    src         source dataset
    var_names   list of variable names to average
    '''

    for var_name in var_names:
        print(f'Averaging {var_name}...', end='\r')
        modified_var, var_shape = src.variables[var_name][:], src.variables[var_name].shape
        if len(var_shape) == 3:
            for timestep in range(var_shape[0]):
                average_value = np.mean(src.variables[var_name][timestep])
                modified_var[timestep][:] = average_value
        elif len(var_shape) == 4:
            for timestep in range(var_shape[0]):
                for height in range(var_shape[1]):
                    average_value = np.mean(src.variables[var_name][timestep][height])
                    modified_var[timestep][height][:] = average_value

        src.variables[var_name][:] = modified_var

    return src

# %%
def modify_water_depth(src: Dataset) -> Dataset:
    modified_water_depth = src.variables['WATER_DEPTH'][:]
    modified_water_depth[0][:, :] = -10.0
    src.variables['WATER_DEPTH'][:] = modified_water_depth

    return src

# %%
def modify_remove_initial_wind(src: Dataset) -> Dataset:
    src.variables['U'][:] = np.zeros(src.variables['U'].shape)
    src.variables['U10'][:] = np.zeros(src.variables['U10'].shape)

    src.variables['V'][:] = np.zeros(src.variables['V'].shape)
    src.variables['V10'][:] = np.zeros(src.variables['V10'].shape)

    src.variables['W'][:] = np.zeros(src.variables['W'].shape)

    return src

# %%
def modify_random_initial_winds(src: Dataset) -> Dataset:
    dimensions_u = src.variables['U'].shape
    src.variables['U'][:] = (np.random.rand(*dimensions_u) * 0.2) - 0.1

    dimensions_v = src.variables['V'].shape
    src.variables['V'][:] = (np.random.rand(*dimensions_v) * 0.2) - 0.1

    return src

# %%
def modify_remove_sin_cos_alpha(src: Dataset) -> Dataset:
    src.variables['SINALPHA'][:] = 0
    src.variables['COSALPHA'][:] = 0
    src.variables['E'][:] = 0

    return src

# %%
def modify_reduce_vapor(src: Dataset) -> Dataset:
    src.variables['QVAPOR'][:] *= 0.01
    return src

# %%
def modify_urban_params(src: Dataset) -> Dataset:
    attrs = src.__dict__
    mask = src.variables['LU_INDEX'][0][:] == attrs['ISURBAN']
    urban_vars = {
        'BUILD_SURF_RATIO': 0.25,
        'BUILD_HEIGHT': 1,
        'STDH_URB2D': 0.5,
        'LF_URB2D': 0.25,
    }
    for name, value in urban_vars.items():
        if name == 'LF_URB2D':
            continue
        src.variables[name][0][mask] = value

    for i in range(3):
        src.variables['LF_URB2D'][0][i][mask] = urban_vars['LF_URB2D']
    return src

#%%

import os

file_name: str = 'wrfinput_d01'
output_name: str = root_dir + 'modified-files/' + file_name

if len(glob(output_name)) > 0:
    os.remove(output_name)

with Dataset(all_files[0], 'r', format='NETCDF4') as src:
    with Dataset(output_name, 'w', format='NETCDF4') as out:
        # Get the attributes of the original file
        attributes = src.__dict__

        # Add extra field to attrs, e.g. notes
        attributes['TITLE'] += ' (MODIFIED)'
        attributes['NOTE'] = 'Idealized land-water split by Mok'

        # Set it into the output
        out.setncatts(attributes)

        # Copy dimensions
        for name, dimension in src.dimensions.items():
            dimension_size = (
                len(dimension) if not dimension.isunlimited() else None
            ) # The value should be None for unlimited dimension

            # Create the dimension with its size, make sure to modify it
            # if you changed the variable dimension
            out.createDimension(name, dimension_size)

        # Modify the variable, see function on the cell above

        for name, variable in src.variables.items():
            out.createVariable(
                name,
                variable.datatype,
                variable.dimensions,
                zlib = True,            # Lossless compression (optional)
                complevel = 5,          # Lossless compression (optional)
                shuffle = True          # Lossless compression (optional)
            )

            # Set output variable attributes
            out[name].setncatts(src[name].__dict__)
            out[name][:] = src[name][:]

        # out = modify_water_depth(out)
        out = modify_remove_initial_wind(out)
        # out = modify_random_initial_winds(out)
        out = modify_remove_sin_cos_alpha(out)
        # out = modify_reduce_vapor(out)
        out = modify_urban_params(out)

        var_names = [ 'T', 'THM', 'MU', 'P', 'AL', 'P_HYD', 'Q2', 'T2', 'TH2',
            'PSFC', 'QVAPOR', 'TSLB', 'TMN', 'TSK', 'SST', 'VAR',
            'CON', 'VAR_SSO', 'OA1', 'OA2', 'OA3', 'OA4',
            'OL1', 'OL2', 'OL3', 'OL4',
        ]
        out = modify_convert_uniform(out, var_names)

    print('Done! Congrats 🎉')

# %%
import subprocess

if is_py:
    subprocess.call(['mv', output_name, all_files[0]])
else:
    # Test reading output file
    out_dataset = Dataset(output_name)
    plot_all_vars(out_dataset)
